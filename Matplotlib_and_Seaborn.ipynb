# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunalwagh107/n-python-numpy-pandas/blob/main/Matplotlib_and_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *# Matplotlib*

# %% [markdown]
# ## database connection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# types of data -
'''
- Numerical -> Numbers, temp, age
- Categorical -> groups, branch, gender

- uni/bi/multivariate -> based on cloumns plotted

'''
# Out:
# '\n- Numerical -> Numbers, temp, age\n- Categorical -> groups, branch, gender\n\n- uni/bi/multivariate -> based on cloumns plotted\n\n'

# %%
# check what kind of data feeds into each graph, to manage it accordingly

# %% [markdown]
# ## *# 2D line plot*

# %%
# -> use for bivariate analysis
# -> num to num / categorical and numerical (most useful)
# -> use cases -> timeseries data

# %%
# plotting a simple function
price = [1000,2000,3444,2434,8765,3223]
year = [2020,2021,2022,2023,2024,2025]

plt.plot(year,price) # (x,y) # x -> categorical/segmentated_data  y -> numerical

# %%
batsman = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %% [markdown]
# ### *- single plot*

# %%
# single plot
plt.plot(batsman['index'],batsman['V Kohli'])

# %% [markdown]
# ### *- multiple plot*

# %%
# multiple plotting
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

# %% [markdown]
# ### *formatting line plot*

# %% [markdown]
# #### *- title and label*

# %%
# provide title and x-y label

plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
# Out:
# Text(0, 0.5, 'RUNS SCORED')

# %% [markdown]
# #### *- color*

# %%
# what if want to change the colour

plt.plot(batsman['index'],batsman['V Kohli'],color='red')
plt.plot(batsman['index'],batsman['RG Sharma'],color ='#0A64F5')# <-- can provide any hex code

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
# Out:
# Text(0, 0.5, 'RUNS SCORED')

# %% [markdown]
# #### *- linestyle and linewidth*

# %%
# changing the linestyle and linewidth

# linestyle -> solid(d)/dashed/dotted/dashdot or -/--/:/-.
# linewidth -> 1.5(d)

plt.plot(batsman['index'],batsman['V Kohli'],color='red',linestyle = 'dashed',linewidth=2)
plt.plot(batsman['index'],batsman['RG Sharma'],color ='#0A64F5',linestyle ='-.',linewidth = 1)

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
# Out:
# Text(0, 0.5, 'RUNS SCORED')

# %% [markdown]
# #### *- marker and markersize*

# %%
# manipulate markers and markersize
'''
'o': circle
's': square
'*': star
'+': plus sign
'x': x mark
'^': triangle up
'v': triangle down
'D': diamond
'.': point (small dot)
',': pixel (tiny dot)
'h': hexagon
'p': pentagon
 '''
 # markersize or ms  -> default is 6

plt.plot(batsman['index'],batsman['V Kohli'],color='red',marker='x',markersize = 15)
plt.plot(batsman['index'],batsman['RG Sharma'],color ='#0A64F5',marker ='o')

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
# Out:
# Text(0, 0.5, 'RUNS SCORED')

# %% [markdown]
# #### *- labels and legend*

# %%
# adding lables and legends
# -> we have to provide lables first to see the legends

plt.plot(batsman['index'],batsman['V Kohli'],color='red',marker='x',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color ='#0A64F5',marker ='o',label ='Rohit')

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
plt.legend(loc= 'best') # -> all options exist

# %% [markdown]
# #### *- limiting axes*

# %%
# limiting axes -> can trim
# -> used when outlier exist in the system and disrupt the variation

price = [1000,2000,3444,2434,8765,32423]
year = [2020,2021,2022,2023,2024,2025]

plt.plot(year,price)
plt.ylim(0,20000)
# Out:
# (0.0, 20000.0)

# %% [markdown]
# #### *- grids*

# %%
# grids -> used to turn on gridlines
# show -> in colab like print it executes automatically but in other id we need to execute command to show

plt.plot(batsman['index'],batsman['V Kohli'],color='red',marker='x',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color ='#0A64F5',marker ='o',label ='Rohit')

plt.title('KOHLI vs SHARMA IPL CARRER')
plt.xlabel('SEASON')
plt.ylabel('RUNS SCORED')
plt.legend()
plt.grid(color='lightgray', linestyle=':', linewidth=0.7)

plt.show() # <-- this prints the graph in other ids

# %% [markdown]
# ## *# Scatterplot*

# %%
# bivariate analysis -> if we join the lines we will get lineplot
# numerical vs numerical analysis
# -> used to find correletion

# %% [markdown]
# ### - basic scatterplots

# %%
x = np.linspace(-10,10,1000)
y = 10*x + 3 + np.random.randint(0,300,1000)

# %%
plt.scatter(x,y) # <-- syntax

# %%
df = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/batter.csv')
df = df.head(100).copy()

# %%
plt.scatter(df['avg'],df['strike_rate'],color='black')
# -> can apply other function as well! marker,grid
plt.title('Average and Strike Rate Top 100 batsman')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# ### *formatting scatterplot*

# %% [markdown]
# #### *- custom point size s =*

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# total bill vs tip

plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)
# s = markersize and we can change it according to input

plt.title('Total Bill vs Tips')
plt.xlabel('Total Bill')
plt.ylabel('Tips')
# Out:
# Text(0, 0.5, 'Tips')

# %%
# plotting using plt. as  scatterplot ->
plt.plot(tips['total_bill'],tips['tip'],'o') # -> Faster technique
# - 'o' used when all points should look identical as in scatterplot we can customize each point

# %% [markdown]
# #### *- color based on split*

# %%
iris = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['Species'].unique()

iris['Species'] = iris['Species'].map({'Iris-setosa' : 0, 'Iris-versicolor':1, 'Iris-virginica':2})

# %%
# coloured scatterplots

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm' ],c=iris['Species'],cmap='winter',alpha=0.4)
# c  -> means ?
# -> can user different kind of cmaps
# -> alpha for opesity
plt.xlabel('Sapal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ### annotations

# %%
bat = pd.read_csv("/content/drive/MyDrive/4. Data Files/Matplotlib/batter.csv")
df = bat.sort_values(['runs','avg','strike_rate'],ascending=False).head(25).copy()
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs']/10) # size based on runs

# plt.text(x,y,'Value_name')

for i in range(df['avg'].shape[0]):
  plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],df['batter'].iloc[i],fontdict={'size':9,"color":'black'})

plt.xlabel('Average')
plt.ylabel('Strike Rate')
plt.show()

# for idx, row in df.iterrows():
#     plt.text(row['avg'], row['strike_rate'], row['batter'])

# can do this as well

# %% [markdown]
# ### plot horizontal and vertical lines

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs']/10)

for i in range(df['avg'].shape[0]):
  plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],df['batter'].iloc[i])
plt.xlabel('Average')
plt.ylabel('Strike Rate')

plt.axhline(135,color='red') # -> horizontal strike rate
plt.axhline(140,color='green') # -> horizontal strike rate
plt.axvline(35,color='red')
plt.show()

# %% [markdown]
# ## *# Bar Chart*

# %%
# x axis -> categorical column
# y axis -> aggregate column numeric
# numerical vs Categorical
# -> analysis of groups

# %%
children = [310,234,345,123,232]
color = ['red','green','blue','orange','black']

# %% [markdown]
# ### *- vertical bar*

# %%
plt.bar(color, children,color='black')
# -> can do all the operations we did above
plt.title('Children vs Favourite Color')
plt.xlabel('Color')
plt.ylabel('Total Children')
# Out:
# Text(0, 0.5, 'Total Children')

# %% [markdown]
# ### *- Horizontal bar*

# %%
# if categories are increased then keep it as horizontal else keep it as vertical
# .barh(x,y)

plt.barh(color, children,color='black')

plt.title('Children vs Favourite Color')
plt.ylabel('Color')
plt.xlabel('Total Children')
# Out:
# Text(0.5, 0, 'Total Children')

# %% [markdown]
# ### *- Grouped bar chart*

# %%
df = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
# Sample data
batsmen = df['batsman'].tolist()
x = np.arange(len(batsmen))  # X-axis positions [0,1,2,3,4]
width = 0.2  # Width of each bar

# Create bars with shifted positions
plt.bar(x - width, df['2015'], width=width, label='2015')
plt.bar(x, df['2016'], width=width, label='2016')
plt.bar(x + width, df['2017'], width=width, label='2017')

# Customize
plt.xticks(x, batsmen)  # Set batsman names at center positions
plt.ylabel('Runs')
plt.xlabel('Batsman')
plt.legend()
plt.tight_layout()

plt.show()

# %%
# what if we have more categorical names ->
children = [310,234,345,123,232]
color = ['redredredredredred','greengreengreengreengreengreengreen','blueblueblueblueblueblue','orange','black']

# %% [markdown]
# #### *-- change label angle*

# %%
plt.bar(color, children,color='black')
# -> can do all the operations we did above
plt.title('Children vs Favourite Color')
plt.xlabel('Color')
plt.ylabel('Total Children')
# Out:
# Text(0, 0.5, 'Total Children')

# %%
# to correct it we will change the rotation angle

plt.bar(color, children,color='black')
plt.title('Children vs Favourite Color')
plt.xlabel('Color')
plt.ylabel('Total Children')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### *- Stacked Bar chart*

# %%
# stacked bar chart ->
# we have to use the command bottom = pervious column to adjust
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'],df['2015'],label='2015')
plt.bar(df['batsman'],df['2016'],bottom=df['2015'],label='2016')
plt.bar(df['batsman'],df['2017'],bottom=df['2015']+df['2016'],label='2017')

plt.legend()

# %% [markdown]
# ## *# Histogram*

# %%
# Univariate analysis -> one column at a time -> frequency count
# numerical column -> bar for category -> histogram for numerical column

# %%
data =data = [
  34, 41, 55, 62, 48, 59, 53, 45, 67, 50,
  72, 38, 44, 56, 61, 47, 52, 49, 58, 63,
]

plt.hist(data)  # <-- bins are calculated as per data
plt.show()

# %% [markdown]
# ### *- custom bins*

# %%
df = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/vk.csv')
df
# Out:
#      match_id  batsman_runs
# 0          12            62
# 1          17            28
# 2          20            64
# 3          27             0
# 4          30            10
# ..        ...           ...
# 136       624            75
# 137       626           113
# 138       632            54
# 139       633             0
# 140       636            54
#
# [141 rows x 2 columns]

# %%
plt.hist(df['batsman_runs'],bins=[0,10,20,30,40,60,70,90,110,120 ])
plt.show()

# %% [markdown]
# ### *- log scale histogram*

# %%
arr = np.load('/content/drive/MyDrive/4. Data Files/Matplotlib/big-array.npy')
arr.shape
# Out:
# (11949,)

# %%
plt.hist(arr)
plt.show() # some bins has so much more data that we can's see other data

# %%
# we can use log scale  # -> get more information about log
plt.hist(arr,log=True)
plt.show()

# %% [markdown]
# ## *# Pie Chart*

# %%
# univariate / bivariate Analysis
# categorical vs numerical
# -> to find contribution

# %%
l = [23,134,145,156,123]
lables = ['AI','ML','STAT','MATH','DL']
plt.pie(l,labels=lables) # <-- no need the sum to be 100 -> calculates percentage
plt.show()

# %%
df = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/gayle-175.csv')
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %% [markdown]
# ### *- show percentage symbol*

# %%
plt.pie(df['batsman_runs'],labels=df['batsman'],autopct='%0.1f%%')
plt.show()
# to show percentage --> autopct -> check documentations

'''
# 1 decimal place with % symbol
autopct='%0.1f%%'  # Output: 25.3%

# 2 decimal places
autopct='%.2f%%'   # Output: 25.34%

# No decimal places (integer)
autopct='%.0f%%'   # Output: 25%

# Without % symbol
autopct='%.1f'     # Output: 25.3
 '''
# Out:
# "\n# 1 decimal place with % symbol\nautopct='%0.1f%%'  # Output: 25.3%\n\n# 2 decimal places\nautopct='%.2f%%'   # Output: 25.34%\n\n# No decimal places (integer)\nautopct='%.0f%%'   # Output: 25%\n\n# Without % symbol\nautopct='%.1f'     # Output: 25.3\n "

# %%
plt.pie(df['batsman_runs'],labels=df['batsman'],colors=['lightblue','red','red','gray','orange','pink'])
plt.show()

# %% [markdown]
# ### *- extract pie*

# %%
# can extract perticular pie
plt.pie(df['batsman_runs'],labels=df['batsman'],explode=[0,0,0,0.7,0,0])
plt.show()

# %%
# Shadow -
plt.pie(df['batsman_runs'],labels=df['batsman'],explode=[0,0,0,0.7,0,0],shadow=True)
plt.show()

# %% [markdown]
# ## ---------

# %% [markdown]
# ## *# style*

# %%
plt.style.available # <- these are the available style and will modify fig style
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('default')

# %% [markdown]
# ## *# Export graph*

# %%
l = [23, 134, 145, 156, 123]
labels = ['AI', 'ML', 'STAT', 'MATH', 'DL']

plt.pie(l, labels=labels)
plt.savefig('pie_chart.png')  # Save FIRST
plt.show()                     # Show SECOND
# plt clears the image therefore it should come first

# %%
# documentation of matplot lib

# %%
# https://matplotlib.org/stable/gallery/index.html

# %%
# check the documentation which graphs are useful and then incorporate it

# %% [markdown]
# ## ---------

# %% [markdown]
# # *# Advanced matplotlib*

# %% [markdown]
# ## database connection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
l = [23,134,145,156,123]
lables = ['AI','ML','STAT','MATH','DL']
children = [310,234,345,123,232]
color = ['red','green','blue','orange','black']
bat = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/batter.csv')

# %% [markdown]
# ## *# Subplots*

# %%
# plotting multiple graphs
#-> alternate way of plotting graphs in plt

# %%
# There are 2 ways to create subplots

# 1 ->

fig, ax = plt.subplots(nrows=2,ncols=2,sharex=True) # <- can define col and rows + fig size

# and then we index ax and start adding plots by indexing ax (axis object)
ax[0,0].scatter(bat['avg'],bat['strike_rate'])
ax[0,1].scatter(bat['avg'],bat['strike_rate'])
ax[1,0].scatter(bat['avg'],bat['strike_rate'])
ax[1,1].scatter(bat['avg'],bat['strike_rate'])


fig.tight_layout() # <-h_pad=3.0 this will add padding
fig.show()

# %%
 # 2. ->

fig = plt.figure() # we create figure object first

#------
ax1 = fig.add_subplot(2,2,1) # and start adding axis in it one by one
ax1.scatter(bat['avg'],bat['strike_rate'])
#------
ax2 = fig.add_subplot(2,2,2) # row,column,number
ax2.scatter(bat['avg'],bat['strike_rate'])
#------
ax3 = fig.add_subplot(2,2,3)
ax3.scatter(bat['avg'],bat['strike_rate'])
#------
ax3 = fig.add_subplot(2,2,4)
ax3.scatter(bat['avg'],bat['strike_rate'])


fig.tight_layout() # <-h_pad=3.0 this will add padding
fig.show()


# use cases

# -> when layout is even and all subplots are in same dimension the go for up
# -> for hyper customization we can use this layout
# -> sharex = True only works in plt.subplots()

# %%
# 3 ->

fig , ax = plt.subplot_mosaic([['A','B'],['C','C'],['D','E']],figsize=(10,6))

# and index A,B,C,D to generate layout
ax['A'].pie(l,labels=lables)
ax['B'].hist(bat['avg'])
ax['C'].barh(color, children,color='black')
ax['D'].scatter(bat['avg'],bat['strike_rate'])
ax['E'].scatter(bat['avg'],bat['runs'])


fig.tight_layout() # <-h_pad=3.0 this will add padding
fig.show()

# %% [markdown]
# ### *- example*

# %%
# design 4*4 graph

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,6),sharex=True)

# here axis is 2D array and we need to index according to it

ax[0,0].scatter(bat['avg'],bat['strike_rate'],color='red')
ax[0,0].set_title('Average vs Strike_rate')
ax[0,0].set_xlabel('Average')
ax[0,0].set_ylabel('Strike_rate')
#-----------------------------------------
ax[0,1].scatter(bat['avg'],bat['runs'],color='red')
ax[0,1].set_title('Average vs Runs')
ax[0,1].set_xlabel('Average')
ax[0,1].set_ylabel('Runs')
#-----------------------------------------
ax[1,0].hist(bat['avg'],color='black')
ax[1,0].set_title('Histogram_Average')
ax[1,0].set_xlabel('Average')
ax[1,0].set_ylabel('Total Number of Players')
#-----------------------------------------
ax[1,1].hist(bat['avg'],color='black')
ax[1,1].set_title('Histogram_Strike_rate')
ax[1,1].set_xlabel('Strike_rate')
ax[1,1].set_ylabel('Total Number of Players')
#---------------------------------------------

plt.tight_layout()
fig.show()

# %%
# basic logic is -> if we put 2 graphs together -> they will overlap one on top of other
#  -> unless we spacigy it via subplots

# %%
# alternative syntax

fig = plt.figure()

ax1 = fig.add_subplot(2,2,1) # rows,column,position
ax1.scatter(bat['avg'],bat['strike_rate'],color='red')
#-----------------------------------------------------
ax2 = fig.add_subplot(2,2,2) # rows,column,position
ax2.hist(bat['strike_rate'],color='black')
#-----------------------------------------------------
ax3 = fig.add_subplot(2,2,(3,4)) # <--- for occupying both positions
ax3.scatter(bat['avg'],bat['runs'],color='black')

# %% [markdown]
# ## *# 3D plots*

# %% [markdown]
# ### *- 3D scatterplot*

# %%
# 3D scatterplot  -> this syntax is industry standard but with other syntax
# -> we get more control about multiple plots

fig, ax = plt.subplots(subplot_kw={"projection":'3d'})

ax.scatter3D(bat['avg'],bat['runs'],bat['strike_rate'])

fig.tight_layout()
fig.show()

# %% [markdown]
# ### *- 2D and 3D together*

# %%
fig = plt.figure(figsize=(10,6))

ax1 = fig.add_subplot(1,2,1,projection='3d')
ax1.scatter3D(bat['avg'],bat['runs'],bat['strike_rate'],s=bat['runs']/100) # <- can provide size
ax2 = fig.add_subplot(1,2,2)
ax2.hist(bat['strike_rate'],color='black')

plt.tight_layout(pad=3.5)
plt.show()

# %% [markdown]
# ### *- 3D lineplot*

# %%
# t = np.linspace(0, 10, 10)
# x = t
# y = 5 * (t**2) + 3
# z = 5 * (t**7) - 4

x = [0, 1, 5, 25]
y = [0, 10, 13, 0]
z = [0, 13, 20, 9]

fig = plt.figure(figsize=(10,6))

ax1 = fig.add_subplot(1,1,1,projection='3d')
ax1.plot3D(x,y,z,marker = 'o',markersize=10,color='red',markerfacecolor='black')


plt.show()

# %% [markdown]
# ### *- 3D surface plot*

# %%
# 3d Surface plots

# -> used in plotting loss function

# %%
# x**2 + y**2

x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)
z = xx**2 + yy**2

# %%
fig = plt.figure()

ax = fig.add_subplot(projection='3d')
k = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(k) # for colourbar -> we need to store it in variable to show
plt.show()

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure()

ax = fig.add_subplot(projection='3d')
k = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(k) # for colourbar -> we need to store it in variable to show
plt.show()

# %% [markdown]
# ## *# Contour Plot*

# %%
# contour plot
# represents 3D graph to 2D - Upper graph to coutour -> seeing from top

# %%
fig = plt.figure()

ax = fig.add_subplot()
k = ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(k) # for colourbar -> we need to store it in variable to show
plt.show()

# %% [markdown]
# ### *- filled contour plot*

# %%
# filled contour graph =>
fig = plt.figure()

ax = fig.add_subplot()
k = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(k) # for colourbar -> we need to store it in variable to show

# %%
# Filled contour graph
fig = plt.figure(figsize=(12,5))

# Left plot - filled contour
ax1 = fig.add_subplot(1, 2, 1)
k = ax1.contourf(xx, yy, z, cmap='viridis')  # Changed ax to ax1
fig.colorbar(k, ax=ax1)  # Added ax parameter
ax1.set_title('Filled Contour')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Right plot - line contour
ax2 = fig.add_subplot(1, 2, 2)
l = ax2.contour(xx, yy, z, cmap='viridis')  # Changed ax to ax2
fig.colorbar(l, ax=ax2)  # Added ax parameter
ax2.set_title('Line Contour')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## *# Heatmap*

# %%
# convert grid to graph and how values are distributed
# 2 categorical variable side by side

# %%
ball = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/IPL_Ball_by_Ball_2008_2022.csv')

# %%
ball
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df = ball[(ball['total_run'] == 6) | (ball['total_run'] == 7)]

df1 = df.groupby(['overs','ballnumber'])['total_run'].count().copy() # or can run pivot

df2 = df1.unstack().loc[:,1:6]

# %%
df2
# Out:
# ballnumber      1      2      3      4      5      6
# overs
# 0             9.0   17.0   31.0   39.0   33.0   27.0
# 1            31.0   40.0   49.0   56.0   58.0   54.0
# 2            75.0   62.0   70.0   72.0   58.0   76.0
# 3            60.0   74.0   74.0  103.0   74.0   71.0
# 4            71.0   77.0  112.0   80.0   81.0   72.0
# 5            77.0  102.0   63.0   86.0   78.0   80.0
# 6            34.0   56.0   49.0   59.0   64.0   38.0
# 7            59.0   62.0   73.0   70.0   69.0   56.0
# 8            86.0   83.0   79.0   81.0   73.0   52.0
# 9            54.0   62.0   86.0   61.0   74.0   67.0
# 10           82.0   92.0   83.0   69.0   72.0   70.0
# 11           91.0   72.0   87.0   79.0   87.0   70.0
# 12           87.0  109.0   79.0  100.0  100.0   84.0
# 13          101.0  101.0   99.0   97.0   90.0   88.0
# 14           90.0  124.0  103.0  100.0   86.0  106.0
# 15          102.0  120.0  129.0  121.0  113.0   96.0
# 16          107.0  115.0  111.0  100.0  120.0  101.0
# ...

# %%
grid = df.pivot_table(index='overs',columns='ballnumber',values='total_run',aggfunc='count')
grid = grid.loc[:,1:6]

# %%
plt.figure(figsize=(12,12))

plt.imshow(grid)

plt.colorbar()
# usually we plot it accordingly seaborn

# %% [markdown]
# # *# Pandas Plot*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plot it function within pandas from which we can plot matplotlib plots

# %% [markdown]
# ## *on Series*

# %%
s = pd.Series([1,2,3,4,5,6,7,8,9,9,9,50,30,40,-20])
s.plot(kind='line') # can be bar/barh/hist/box/area/pie/kde(kernal_density_fun)
#s.plot(kind='bar')
# Out:
# <Axes: >

# %%
s.plot(kind='box')  # outlier
# Out:
# <Axes: >

# %% [markdown]
# ## *on DataFrame*

# %% [markdown]
# ### *- scatterplot*

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# scatterpolot

tips.plot(kind='scatter',y = 'tip',x='total_bill',title='Cost Analysis',figsize=(10,5),marker='x',c='sex',cmap='viridis')
# ,color='red' -> can only put this or c for split
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### *- Lineplot*

# %%
stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks.loc[:,['Date','MSFT','FB']].plot(kind='line',x ='Date') # asking on DB
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### *- bar chart*

# %%
# row by row plotting -> tips.loc[:,['sex','total_bill']].plot(kind='bar',x='sex')

tips.groupby('sex',observed=False)['total_bill'].sum().plot(kind='bar')
# can specify x and y as well
# Out:
# <Axes: xlabel='sex'>

# %%
bat = pd.read_csv('/content/drive/MyDrive/4. Data Files/Matplotlib/batsman_season_record.csv')
bat
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
bat.plot(kind='bar',x='batsman')
# Out:
# <Axes: xlabel='batsman'>
